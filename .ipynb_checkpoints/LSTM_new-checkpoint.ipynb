# %%
#读取数据
import datetime
import pandas_datareader.data as pd_data
def dataload():
    start = datetime.datetime(2000, 1, 1)
    end = datetime.datetime(2021, 11, 18)
    df = pd_data.DataReader('GOOGL', 'stooq', start, end)
    return df

# %%
import numpy as np
from collections import deque
from sklearn.preprocessing import StandardScaler

#数据预处理
def Stock_Price_LSTM_Data_Preprocessing (df, mem_his_days, pre_days):
    df.dropna(inplace=True)  # 删除0
    df.sort_index(inplace=True)
    # inplace(原地)排序，根据之前传进来的日期
    df['label'] = df['Close'].shift(-pre_days)  # Close收盘价往上移pre_days个再加到新的label列作为标签
    scalar  = StandardScaler()
    sca_X = scalar.fit_transform(df.iloc[:, :-1])  #

    deq = deque(maxlen=mem_his_days)
    # 队列的最大长度为记忆天数

    X = []
    for i in sca_X:
        list(i)
        deq.append(list(i))
        if len(deq) == mem_his_days:
            X.append(list(deq))
    # X的shape是(4330,mem_his_days,5);每个样本存的是(mem_his_days，5)的shape
    # 每次fori的时候，i是一个5的张量，然后每次X.append5个张量，
    # 也就是说mem_his_days天的数据*每天的5个特征
    X_latey = X[-pre_days:]
    # 少的是(0,men_his_days-1)个，序列未满时的值
    X = X[:-pre_days]
    # 删掉nan的值。
    # 得到纯粹的训练集
    y = df['label'][mem_his_days - 1:-pre_days]

    X = np.array(X)
    # 4330个样本，每个样本有(5天*每天5个特征)
    y = np.array(y)

    print(len(X))
    print(len(y))
    print(len(X_latey))
    return X, y, X_latey

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
def init_model(the_lstm_layers, the_dense_layers, the_units):
    model = Sequential()
    # 序列添加
    model.add(LSTM(the_units, input_shape=X.shape[1:], activation='relu', return_sequences=True))
    model.add(Dropout(0.1))

    for i in range(the_lstm_layers):
        model.add(LSTM(the_units, activation='relu', return_sequences=True))
        model.add(Dropout(0.1))

    model.add(LSTM(the_units, activation='relu'))
    model.add(Dropout(0.1))

    for i in range(the_dense_layers):
        model.add(Dense(the_units, activation='relu'))
        model.add(Dropout(0.1))

    model.add(Dense(1))

    model.compile(optimizer="Adam", loss="mse", metrics=["mape"])
    # MeanAbsolutePercentageError 平均绝对百分比误差 metrics(度量)
    # MeanSquaredError 均方误差
    # LSTM，10个神经元
    return model

# %%
from keras.models import load_model
import os


#找一个最好的数据进行预测
def model_load():
    files = os.listdir('./model')
    best_model = load_model(f'./models/{files.sort()[0]}')
    return best_model

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint

df = dataload()

# model = model()
# model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test))

# 多模型训练
mem_days = [5, 10, 15]
lstm_layers = [1, 2, 3, 4]
dense_layers = [1, 2, 3]
units = [8, 16, 32]
pre_days = 10
# 一共训练3*4*3*3个模型
os.removedirs('./models')
for the_mem_days in mem_days:
    for the_lstm_layers in lstm_layers:
        for the_dense_layers in dense_layers:
            for the_units in units:
                filepath = './models/{val_mape:.2f}_{epoch:02d}-' + f'mem_{the_mem_days}_lstm_{the_lstm_layers}_dense_{the_dense_layers}_units_{the_units}'
                checkpoint_callback = ModelCheckpoint(
                    filepath=filepath,
                    save_weights_only=False,
                    monitor='val_mape',
                    mode='min',
                    save_best_only=True)
                X, y, X_latey = Stock_Price_LSTM_Data_Preprocessing(df, the_mem_days, pre_days)
                X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.1)
                model = init_model(the_lstm_layers, the_dense_layers, the_units)
                model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test), callbacks=[checkpoint_callback])
best_model = model_load()
print(best_model.summary())
print(best_model.evaluate(X_test,y_test))
# Out:
# 4330
# 4330
# 10
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 122/122 [==============================] - ETA: 0s - loss: 346687.5938 - mape: 96.7723INFO:tensorflow:Assets written to: ./models\161.27_01-mem_5_lstm_1_dense_1_units_8\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022028BF2160> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022028D43CD0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000002202F632F70> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 122/122 [==============================] - 27s 183ms/step - loss: 346687.5938 - mape: 96.7723 - val_loss: 17846084.0000 - val_mape: 161.2742
# Epoch 2/50
# 122/122 [==============================] - ETA: 0s - loss: 80946.2969 - mape: 51.1902INFO:tensorflow:Assets written to: ./models\34.39_02-mem_5_lstm_1_dense_1_units_8\assets
# INFO:tensorflow:Assets written to: ./models\34.39_02-mem_5_lstm_1_dense_1_units_8\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022028BF2160> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022028D43CD0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000002202F632F70> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 122/122 [==============================] - 21s 173ms/step - loss: 80946.2969 - mape: 51.1902 - val_loss: 1010658.1250 - val_mape: 34.3946
# Epoch 3/50
# 122/122 [==============================] - ETA: 0s - loss: 32225.8262 - mape: 30.5032INFO:tensorflow:Assets written to: ./models\14.97_03-mem_5_lstm_1_dense_1_units_8\assets
# INFO:tensorflow:Assets written to: ./models\14.97_03-mem_5_lstm_1_dense_1_units_8\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022028BF2160> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022028D43CD0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000002202F632F70> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 122/122 [==============================] - 20s 166ms/step - loss: 32225.8262 - mape: 30.5032 - val_loss: 165296.4844 - val_mape: 14.9742
# Epoch 4/50
# 122/122 [==============================] - ETA: 0s - loss: 25819.2461 - mape: 26.9314
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\ops\array_ops.py in zeros(shape, dtype, name)
#    2969         shape = constant_op._tensor_shape_tensor_conversion_function(
# -> 2970             tensor_shape.TensorShape(shape))
#    2971       except (TypeError, ValueError, errors.UnimplementedError):
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\tensor_shape.py in __init__(self, dims)
#     774     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 775       self._dims = [Dimension(d) for d in dims]
#     776     elif dims is None:
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\tensor_shape.py in <listcomp>(.0)
#     774     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 775       self._dims = [Dimension(d) for d in dims]
#     776     elif dims is None:
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\tensor_shape.py in __init__(self, value)
#     215       except AttributeError:
# --> 216         six.raise_from(
#     217             TypeError("Dimension value must be integer or None or have "
#
# E:\miniconda3\envs\Python38\lib\site-packages\six.py in raise_from(value, from_value)
#
# TypeError: Dimension value must be integer or None or have an __index__ method, got value '<tf.Tensor 'strided_slice:0' shape=() dtype=int32>' with type '<class 'tensorflow.python.framework.ops.Tensor'>'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15972/2020635094.py in <module>
#      29                 X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.1)
#      30                 model = init_model(the_lstm_layers, the_dense_layers, the_units)
# ---> 31                 model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test), callbacks=[checkpoint_callback])
#      32 best_model = model_load()
#      33 print(best_model.summary())
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1265           epoch_logs.update(val_logs)
#    1266
# -> 1267         callbacks.on_epoch_end(epoch, epoch_logs)
#    1268         training_logs = epoch_logs
#    1269         if self.stop_training:
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     412     logs = self._process_logs(logs)
#     413     for callback in self.callbacks:
# --> 414       callback.on_epoch_end(epoch, logs)
#     415
#     416   def on_train_batch_begin(self, batch, logs=None):
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#    1374     # pylint: disable=protected-access
#    1375     if self.save_freq == 'epoch':
# -> 1376       self._save_model(epoch=epoch, batch=None, logs=logs)
#    1377
#    1378   def _should_save_on_batch(self, batch):
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\callbacks.py in _save_model(self, epoch, batch, logs)
#    1428                     filepath, overwrite=True, options=self._options)
#    1429               else:
# -> 1430                 self.model.save(filepath, overwrite=True, options=self._options)
#    1431             else:
#    1432               if self.verbose > 0:
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\engine\training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2189     """
#    2190     # pylint: enable=line-too-long
# -> 2191     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2192                     signatures, options, save_traces)
#    2193
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     149   else:
#     150     with generic_utils.SharedObjectSavingScope():
# --> 151       saved_model_save.save(model, filepath, overwrite, include_optimizer,
#     152                             signatures, options, save_traces)
#     153
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save.py in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      91   with backend.deprecated_internal_learning_phase_scope(0):
#      92     with utils.keras_option_scope(save_traces):
# ---> 93       saved_nodes, node_paths = save_lib.save_and_return_nodes(
#      94           model, filepath, signatures, options)
#      95
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\saved_model\save.py in save_and_return_nodes(obj, export_dir, signatures, options, experimental_skip_checkpoint)
#    1313
#    1314   _, exported_graph, object_saver, asset_info, saved_nodes, node_paths = (
# -> 1315       _build_meta_graph(obj, signatures, options, meta_graph_def))
#    1316   saved_model.saved_model_schema_version = (
#    1317       constants.SAVED_MODEL_SCHEMA_VERSION)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\saved_model\save.py in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1485
#    1486   with save_context.save_context(options):
# -> 1487     return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\saved_model\save.py in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1421   checkpoint_graph_view = _AugmentedGraphView(obj)
#    1422   if signatures is None:
# -> 1423     signatures = signature_serialization.find_function_to_export(
#    1424         checkpoint_graph_view)
#    1425
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\saved_model\signature_serialization.py in find_function_to_export(saveable_view)
#      99   # If the user did not specify signatures, check the root object for a function
#     100   # that can be made into a signature.
# --> 101   functions = saveable_view.list_functions(saveable_view.root)
#     102   signature = functions.get(DEFAULT_SIGNATURE_ATTR, None)
#     103   if signature is not None:
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\saved_model\save.py in list_functions(self, obj)
#     163     obj_functions = self._functions.get(obj, None)
#     164     if obj_functions is None:
# --> 165       obj_functions = obj._list_functions_for_serialization(  # pylint: disable=protected-access
#     166           self._serialization_cache)
#     167       self._functions[obj] = obj_functions
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\engine\training.py in _list_functions_for_serialization(self, serialization_cache)
#    2882     self.predict_function = None
#    2883     self.train_tf_function = None
# -> 2884     functions = super(
#    2885         Model, self)._list_functions_for_serialization(serialization_cache)
#    2886     self.train_function = train_function
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\engine\base_layer.py in _list_functions_for_serialization(self, serialization_cache)
#    3148
#    3149   def _list_functions_for_serialization(self, serialization_cache):
# -> 3150     return (self._trackable_saved_model_saver
#    3151             .list_functions_for_serialization(serialization_cache))
#    3152
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\base_serialization.py in list_functions_for_serialization(self, serialization_cache)
#      91       return {}
#      92
# ---> 93     fns = self.functions_to_serialize(serialization_cache)
#      94
#      95     # The parent AutoTrackable class saves all user-defined tf.functions, and
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\layer_serialization.py in functions_to_serialize(self, serialization_cache)
#      70
#      71   def functions_to_serialize(self, serialization_cache):
# ---> 72     return (self._get_serialized_attributes(
#      73         serialization_cache).functions_to_serialize)
#      74
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes(self, serialization_cache)
#      86       return serialized_attr
#      87
# ---> 88     object_dict, function_dict = self._get_serialized_attributes_internal(
#      89         serialization_cache)
#      90
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\model_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      54     # the ones serialized by Layer.
#      55     objects, functions = (
# ---> 56         super(ModelSavedModelSaver, self)._get_serialized_attributes_internal(
#      57             serialization_cache))
#      58     functions['_default_save_signature'] = default_signature
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      96     """Returns dictionary of serialized attributes."""
#      97     objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
# ---> 98     functions = save_impl.wrap_layer_functions(self.obj, serialization_cache)
#      99     # Attribute validator requires that the default save signature is added to
#     100     # function dict, even if the value is None.
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in wrap_layer_functions(layer, serialization_cache)
#     195       for fn in fns.values():
#     196         if fn is not None and not isinstance(fn, LayerCall):
# --> 197           fn.get_concrete_function()
#     198
#     199   # Restore overwritten functions and losses
#
# E:\miniconda3\envs\Python38\lib\contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in tracing_scope()
#     357       if training is not None:
#     358         with backend.deprecated_internal_learning_phase_scope(training):
# --> 359           fn.get_concrete_function(*args, **kwargs)
#     360       else:
#     361         fn.get_concrete_function(*args, **kwargs)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in get_concrete_function(self, *args, **kwargs)
#    1257   def get_concrete_function(self, *args, **kwargs):
#    1258     # Implements GenericFunction.get_concrete_function.
# -> 1259     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1260     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1261     return concrete
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1237       if self._stateful_fn is None:
#    1238         initializers = []
# -> 1239         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1240         self._initialize_uninitialized_variables(initializers)
#    1241
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     778     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     779     self._concrete_stateful_fn = (
# --> 780         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     781             *args, **kwds))
#     782
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3155       args, kwargs = None, None
#    3156     with self._lock:
# -> 3157       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3158     return graph_function
#    3159
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3390     arg_names = base_arg_names + missing_arg_names
#    3391     graph_function = ConcreteFunction(
# -> 3392         func_graph_module.func_graph_from_py_func(
#    3393             self._name,
#    3394             self._python_function,
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1141         _, original_func = tf_decorator.unwrap(python_func)
#    1142
# -> 1143       func_outputs = python_func(*func_args, **func_kwargs)
#    1144
#    1145       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in wrapper(*args, **kwargs)
#     570       with autocast_variable.enable_auto_cast_variables(
#     571           layer._compute_dtype_object):  # pylint: disable=protected-access
# --> 572         ret = method(*args, **kwargs)
#     573     _restore_layer_losses(original_losses)
#     574     return ret
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in wrap_with_training_arg(*args, **kwargs)
#     163       return wrapped_call(*args, **kwargs)
#     164
# --> 165     return control_flow_util.smart_cond(
#     166         training, lambda: replace_training_and_call(True),
#     167         lambda: replace_training_and_call(False))
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     103     return tf.cond(
#     104         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 105   return tf.__internal__.smart_cond.smart_cond(
#     106       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     107
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      57       return true_fn()
#      58     else:
# ---> 59       return false_fn()
#      60   else:
#      61     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in <lambda>()
#     165     return control_flow_util.smart_cond(
#     166         training, lambda: replace_training_and_call(True),
# --> 167         lambda: replace_training_and_call(False))
#     168
#     169   # Create arg spec for decorated function. If 'training' is not defined in the
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in replace_training_and_call(training)
#     161     def replace_training_and_call(training):
#     162       set_training_arg(training, training_arg_index, args, kwargs)
# --> 163       return wrapped_call(*args, **kwargs)
#     164
#     165     return control_flow_util.smart_cond(
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in call(inputs, *args, **kwargs)
#     650     return layer.keras_api.__call__  # pylint: disable=protected-access
#     651   def call(inputs, *args, **kwargs):
# --> 652     return call_and_return_conditional_losses(inputs, *args, **kwargs)[0]
#     653   return _create_call_fn_decorator(layer, call)
#     654
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in __call__(self, *args, **kwargs)
#     608   def __call__(self, *args, **kwargs):
#     609     self._maybe_trace(args, kwargs)
# --> 610     return self.wrapped_call(*args, **kwargs)
#     611
#     612   def get_concrete_function(self, *args, **kwargs):
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     956       # This is the first call of __call__, so we have to initialize.
#     957       initializers = []
# --> 958       self._initialize(args, kwds, add_initializers_to=initializers)
#     959     finally:
#     960       # At this point we know that the initialization is complete (or less
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     778     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     779     self._concrete_stateful_fn = (
# --> 780         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     781             *args, **kwds))
#     782
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3155       args, kwargs = None, None
#    3156     with self._lock:
# -> 3157       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3158     return graph_function
#    3159
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3390     arg_names = base_arg_names + missing_arg_names
#    3391     graph_function = ConcreteFunction(
# -> 3392         func_graph_module.func_graph_from_py_func(
#    3393             self._name,
#    3394             self._python_function,
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1141         _, original_func = tf_decorator.unwrap(python_func)
#    1142
# -> 1143       func_outputs = python_func(*func_args, **func_kwargs)
#    1144
#    1145       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in wrapper(*args, **kwargs)
#     570       with autocast_variable.enable_auto_cast_variables(
#     571           layer._compute_dtype_object):  # pylint: disable=protected-access
# --> 572         ret = method(*args, **kwargs)
#     573     _restore_layer_losses(original_losses)
#     574     return ret
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in wrap_with_training_arg(*args, **kwargs)
#     163       return wrapped_call(*args, **kwargs)
#     164
# --> 165     return control_flow_util.smart_cond(
#     166         training, lambda: replace_training_and_call(True),
#     167         lambda: replace_training_and_call(False))
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     103     return tf.cond(
#     104         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 105   return tf.__internal__.smart_cond.smart_cond(
#     106       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     107
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      57       return true_fn()
#      58     else:
# ---> 59       return false_fn()
#      60   else:
#      61     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in <lambda>()
#     165     return control_flow_util.smart_cond(
#     166         training, lambda: replace_training_and_call(True),
# --> 167         lambda: replace_training_and_call(False))
#     168
#     169   # Create arg spec for decorated function. If 'training' is not defined in the
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in replace_training_and_call(training)
#     161     def replace_training_and_call(training):
#     162       set_training_arg(training, training_arg_index, args, kwargs)
# --> 163       return wrapped_call(*args, **kwargs)
#     164
#     165     return control_flow_util.smart_cond(
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in call_and_return_conditional_losses(*args, **kwargs)
#     632   def call_and_return_conditional_losses(*args, **kwargs):
#     633     """Returns layer (call_output, conditional losses) tuple."""
# --> 634     call_output = layer_call(*args, **kwargs)
#     635     if version_utils.is_v1_layer_or_model(layer):
#     636       conditional_losses = layer.get_losses_for(
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\engine\sequential.py in call(self, inputs, training, mask)
#     371       if not self.built:
#     372         self._init_graph_network(self.inputs, self.outputs)
# --> 373       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     374
#     375     outputs = inputs  # handle the corner case where self.layers is empty
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\engine\functional.py in call(self, inputs, training, mask)
#     449         a list of tensors if there are more than one outputs.
#     450     """
# --> 451     return self._run_internal_graph(
#     452         inputs, training=training, mask=mask)
#     453
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     587
#     588         args, kwargs = node.map_arguments(tensor_dict)
# --> 589         outputs = node.layer(*args, **kwargs)
#     590
#     591         # Update tensor_dict.
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     677
#     678     if initial_state is None and constants is None:
# --> 679       return super(RNN, self).__call__(inputs, **kwargs)
#     680
#     681     # If any of `initial_state` or `constants` are specified and are Keras
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in return_outputs_and_add_losses(*args, **kwargs)
#      66       args = args[1:]
#      67
# ---> 68     outputs, losses = fn(*args, **kwargs)
#      69     layer.add_loss(losses, inputs=True)
#      70
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in wrap_with_training_arg(*args, **kwargs)
#     163       return wrapped_call(*args, **kwargs)
#     164
# --> 165     return control_flow_util.smart_cond(
#     166         training, lambda: replace_training_and_call(True),
#     167         lambda: replace_training_and_call(False))
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     103     return tf.cond(
#     104         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 105   return tf.__internal__.smart_cond.smart_cond(
#     106       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     107
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      57       return true_fn()
#      58     else:
# ---> 59       return false_fn()
#      60   else:
#      61     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in <lambda>()
#     165     return control_flow_util.smart_cond(
#     166         training, lambda: replace_training_and_call(True),
# --> 167         lambda: replace_training_and_call(False))
#     168
#     169   # Create arg spec for decorated function. If 'training' is not defined in the
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in replace_training_and_call(training)
#     161     def replace_training_and_call(training):
#     162       set_training_arg(training, training_arg_index, args, kwargs)
# --> 163       return wrapped_call(*args, **kwargs)
#     164
#     165     return control_flow_util.smart_cond(
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in __call__(self, *args, **kwargs)
#     608   def __call__(self, *args, **kwargs):
#     609     self._maybe_trace(args, kwargs)
# --> 610     return self.wrapped_call(*args, **kwargs)
#     611
#     612   def get_concrete_function(self, *args, **kwargs):
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     947       # In this case we have not created variables on the first call. So we can
#     948       # run the first trace but we should fail if variables are created.
# --> 949       results = self._stateful_fn(*args, **kwds)
#     950       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     951         raise ValueError("Creating variables on a non-first call to a function"
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3127     with self._lock:
#    3128       (graph_function,
# -> 3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3390     arg_names = base_arg_names + missing_arg_names
#    3391     graph_function = ConcreteFunction(
# -> 3392         func_graph_module.func_graph_from_py_func(
#    3393             self._name,
#    3394             self._python_function,
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1141         _, original_func = tf_decorator.unwrap(python_func)
#    1142
# -> 1143       func_outputs = python_func(*func_args, **func_kwargs)
#    1144
#    1145       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in wrapper(*args, **kwargs)
#     570       with autocast_variable.enable_auto_cast_variables(
#     571           layer._compute_dtype_object):  # pylint: disable=protected-access
# --> 572         ret = method(*args, **kwargs)
#     573     _restore_layer_losses(original_losses)
#     574     return ret
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in wrap_with_training_arg(*args, **kwargs)
#     163       return wrapped_call(*args, **kwargs)
#     164
# --> 165     return control_flow_util.smart_cond(
#     166         training, lambda: replace_training_and_call(True),
#     167         lambda: replace_training_and_call(False))
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\utils\control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     103     return tf.cond(
#     104         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 105   return tf.__internal__.smart_cond.smart_cond(
#     106       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     107
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      57       return true_fn()
#      58     else:
# ---> 59       return false_fn()
#      60   else:
#      61     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in <lambda>()
#     165     return control_flow_util.smart_cond(
#     166         training, lambda: replace_training_and_call(True),
# --> 167         lambda: replace_training_and_call(False))
#     168
#     169   # Create arg spec for decorated function. If 'training' is not defined in the
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\utils.py in replace_training_and_call(training)
#     161     def replace_training_and_call(training):
#     162       set_training_arg(training, training_arg_index, args, kwargs)
# --> 163       return wrapped_call(*args, **kwargs)
#     164
#     165     return control_flow_util.smart_cond(
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\saving\saved_model\save_impl.py in call_and_return_conditional_losses(*args, **kwargs)
#     632   def call_and_return_conditional_losses(*args, **kwargs):
#     633     """Returns layer (call_output, conditional losses) tuple."""
# --> 634     call_output = layer_call(*args, **kwargs)
#     635     if version_utils.is_v1_layer_or_model(layer):
#     636       conditional_losses = layer.get_losses_for(
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\layers\recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1138
#    1139     # LSTM does not support constants. Ignore it during process.
# -> 1140     inputs, initial_state, _ = self._process_inputs(inputs, initial_state, None)
#    1141
#    1142     if isinstance(mask, list):
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\layers\recurrent.py in _process_inputs(self, inputs, initial_state, constants)
#     886       )
#     887     elif initial_state is None:
# --> 888       initial_state = self.get_initial_state(inputs)
#     889
#     890     if len(initial_state) != len(self.states):
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\layers\recurrent.py in get_initial_state(self, inputs)
#     659     dtype = inputs.dtype
#     660     if get_initial_state_fn:
# --> 661       init_state = get_initial_state_fn(
#     662           inputs=None, batch_size=batch_size, dtype=dtype)
#     663     else:
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\layers\recurrent.py in get_initial_state(self, inputs, batch_size, dtype)
#    2545
#    2546   def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
# -> 2547     return list(_generate_zero_filled_state_for_cell(
#    2548         self, inputs, batch_size, dtype))
#    2549
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\layers\recurrent.py in _generate_zero_filled_state_for_cell(cell, inputs, batch_size, dtype)
#    3029     batch_size = tf.shape(inputs)[0]
#    3030     dtype = inputs.dtype
# -> 3031   return _generate_zero_filled_state(batch_size, cell.state_size, dtype)
#    3032
#    3033
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\layers\recurrent.py in _generate_zero_filled_state(batch_size_tensor, state_size, dtype)
#    3045
#    3046   if tf.nest.is_nested(state_size):
# -> 3047     return tf.nest.map_structure(create_zeros, state_size)
#    3048   else:
#    3049     return create_zeros(state_size)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# E:\miniconda3\envs\Python38\lib\site-packages\keras\layers\recurrent.py in create_zeros(unnested_state_size)
#    3042     flat_dims = tf.TensorShape(unnested_state_size).as_list()
#    3043     init_state_size = [batch_size_tensor] + flat_dims
# -> 3044     return tf.zeros(init_state_size, dtype=dtype)
#    3045
#    3046   if tf.nest.is_nested(state_size):
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\ops\array_ops.py in wrapped(*args, **kwargs)
#    2913
#    2914   def wrapped(*args, **kwargs):
# -> 2915     tensor = fun(*args, **kwargs)
#    2916     tensor._is_zeros_tensor = True
#    2917     return tensor
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\ops\array_ops.py in zeros(shape, dtype, name)
#    2971       except (TypeError, ValueError, errors.UnimplementedError):
#    2972         # Happens when shape is a list with tensor elements
# -> 2973         shape = ops.convert_to_tensor(shape, dtype=dtypes.int32)
#    2974     if not shape._shape_tuple():
#    2975       shape = reshape(shape, [-1])  # Ensure it's a vector
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1619
#    1620     if ret is None:
# -> 1621       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1622
#    1623     if ret is NotImplemented:
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1535   elif dtype != inferred_dtype:
#    1536     v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1537   return _autopacking_helper(v, dtype, name or "packed")
#    1538
#    1539
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_helper(list_or_tuple, dtype, name)
#    1471           elems_as_tensors.append(
#    1472               constant_op.constant(elem, dtype=dtype, name=str(i)))
# -> 1473       return gen_array_ops.pack(elems_as_tensors, name=scope)
#    1474     else:
#    1475       return converted_elems
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in pack(values, axis, name)
#    6562     axis = 0
#    6563   axis = _execute.make_int(axis, "axis")
# -> 6564   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6565         "Pack", values=values, axis=axis, name=name)
#    6566   _result = _outputs[:]
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     742       # Add Op to graph
#     743       # pylint: disable=protected-access
# --> 744       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     745                                  name=scope, input_types=input_types,
#     746                                  attrs=attr_protos, op_def=op_def)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     687       inp = self.capture(inp)
#     688       captured_inputs.append(inp)
# --> 689     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     690         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     691         compute_device)
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3695     # Session.run call cannot occur between creating and mutating the op.
#    3696     with self._mutation_lock():
# -> 3697       ret = Operation(
#    3698           node_def,
#    3699           self,
#
# E:\miniconda3\envs\Python38\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2106
#    2107     # Initialize self._outputs.
# -> 2108     num_outputs = pywrap_tf_session.TF_OperationNumOutputs(self._c_op)
#    2109     self._outputs = []
#    2110     for i in range(num_outputs):
#
# KeyboardInterrupt:

# %%
best_model.summary()
best_model.evaluate(X_test,y_test)
pre = best_model.predict(X_test)
print(len(best_model))

# %%
import matplotlib.pyplot as plt

df_time = df.index[-len(y_test)]
print(df_time)
plt.plot(df_time,y_test,color='red',label='price')
plt.plot(df_time,pre,color='blue',label='pre')
plt.show
